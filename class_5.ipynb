# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashraful34/Assignment--02-on-Scaling-/blob/main/class_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-71f125af-d72d-4481-b047-393ac17c631c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71f125af-d72d-4481-b047-393ac17c631c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving supershops.csv to supershops.csv
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('supershops.csv')

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1=df.copy()
df2=df.copy()
df3=df.copy()
df4=df.copy()
df5=df.copy()

# %%
from sklearn.preprocessing import RobustScaler
Ro=RobustScaler()

# %%
df['Marketing Spend']=Ro.fit_transform(df[['Marketing Spend']])

# %%
df.head()
# Out:
#   Marketing Spend  Administration  Transport     Area     Profit
# 0  MinMaxScaler()       136897.80  471784.10    Dhaka  192261.83
# 1  MinMaxScaler()       151377.59  443898.53      Ctg  191792.06
# 2  MinMaxScaler()       101145.55  407934.54  Rangpur  191050.39
# 3  MinMaxScaler()       118671.85  383199.62    Dhaka  182901.99
# 4  MinMaxScaler()        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
ad=scaler.fit(df[['Administration']])

# %%
ad
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#   Marketing Spend  Administration  Transport     Area     Profit
# 0  MinMaxScaler()       136897.80  471784.10    Dhaka  192261.83
# 1  MinMaxScaler()       151377.59  443898.53      Ctg  191792.06
# 2  MinMaxScaler()       101145.55  407934.54  Rangpur  191050.39
# 3  MinMaxScaler()       118671.85  383199.62    Dhaka  182901.99
# 4  MinMaxScaler()        91391.77  366168.42  Rangpur  166187.94

# %%
df['Administration']=scaler.transform(df[['Administration']])

# %%
df.head()
# Out:
#   Marketing Spend  Administration  Transport     Area     Profit
# 0  MinMaxScaler()        0.651744  471784.10    Dhaka  192261.83
# 1  MinMaxScaler()        0.761972  443898.53      Ctg  191792.06
# 2  MinMaxScaler()        0.379579  407934.54  Rangpur  191050.39
# 3  MinMaxScaler()        0.512998  383199.62    Dhaka  182901.99
# 4  MinMaxScaler()        0.305328  366168.42  Rangpur  166187.94

# %%
df.Transport=df.Transport/df.Transport.max()

# %%
df.head()
# Out:
#   Marketing Spend  Administration  Transport     Area     Profit
# 0  MinMaxScaler()        0.651744   1.000000    Dhaka  192261.83
# 1  MinMaxScaler()        0.761972   0.940893      Ctg  191792.06
# 2  MinMaxScaler()        0.379579   0.864664  Rangpur  191050.39
# 3  MinMaxScaler()        0.512998   0.812235    Dhaka  182901.99
# 4  MinMaxScaler()        0.305328   0.776136  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.shape[0]
# Out:
# 50

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-24119aba617a> in <module>()
# ----> 1 df.area[0:20]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'area'
